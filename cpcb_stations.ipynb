# %%
import os
files=os.listdir("/home/rishi/ML Projects/Air Pollution/CPCB/separated")
files=sorted(files)

# %%
site_ids = ['_'.join(file.split('_')[:2]) for file in files]
site_names = ['_'.join(file.split('_')[2:-1]) for file in files]

# %%
import pandas as pd
df=pd.DataFrame({"site_ids":site_ids, "site_names":site_names})
df
# Out:
#        site_ids                   site_names
# 0      site_103  CRRI_Mathura_Road_Delhi_IMD
# 1      site_103  CRRI_Mathura_Road_Delhi_IMD
# 2      site_103  CRRI_Mathura_Road_Delhi_IMD
# 3      site_103  CRRI_Mathura_Road_Delhi_IMD
# 4      site_103  CRRI_Mathura_Road_Delhi_IMD
# ...         ...                          ...
# 3318  site_6061       Khunmoh_Srinagar_JKPCC
# 3319  site_6062          Khrew_Pampore_JKPCC
# 3320  site_6062          Khrew_Pampore_JKPCC
# 3321  site_6062          Khrew_Pampore_JKPCC
# 3322  site_6062          Khrew_Pampore_JKPCC
#
# [3323 rows x 2 columns]

# %%
df=df.drop_duplicates()

# %%
df.to_csv("cpcb_stations.csv", index=False)
