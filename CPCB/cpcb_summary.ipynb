# %%
import pandas as pd
import os

# %%
# def calculate_data_stats(dataframe, filename):
#     # Set 'Timestamp' as index if present
#     if 'Timestamp' in dataframe.columns:
#         dataframe['Timestamp'] = pd.to_datetime(dataframe['Timestamp'], errors='coerce')
#         dataframe = dataframe.set_index('Timestamp')
    
#     stats = {}
#     stats['filename'] = filename
    
#     stats["Years"] = f"{dataframe.index[0]} to {dataframe.index[-1]}"
    
#     stats["Rows"] = dataframe.shape[0]
#     stats["Features"] = dataframe.shape[1]
#     stats["Empty Rows"] = dataframe.isnull().all(axis=1).sum()
    
#     missing_cols = []
#     present_cols = []
#     for p in dataframe.columns:
#         count = dataframe[p].notnull().sum()
#         percent = round(count * 100 / dataframe.shape[0], 2)
#         stats[p] = percent
#         if count == 0:
#             missing_cols.append(p)
#         else:
#             present_cols.append(p)
    
#     stats["Missing Features"] = str(missing_cols)
#     stats["Rows with Missing Values"] = dataframe[present_cols].isnull().any(axis=1).sum() if present_cols else 0
    
#     # Count ADDITIONAL missing (only from present columns)
#     if present_cols:
#         missing_counts = dataframe[present_cols].isnull().sum(axis=1)
#         missing_bins = round((missing_counts.value_counts() * 100 / dataframe.shape[0]), 2).sort_index()
#         for bin_count, percent in missing_bins.items():
#             stats[f'additional_missing_{int(bin_count)}'] = percent
    
#     return stats

# %%
# def batch_data_stats(folder_path, stats_fn):
#     """
#     Runs the given stats function on every CSV file in the folder,
#     appends the overall stats (scalars only) to a list, and returns a DataFrame.
#     """
#     results = []
#     for fname in sorted(os.listdir(folder_path)):
#         if fname.endswith('.csv'):
#             fpath = os.path.join(folder_path, fname)
#             try:
#                 df = pd.read_csv(fpath)
#                 stats = stats_fn(df,fname)
#                 results.append(stats)
#             except Exception as e:
#                 print(f"Error processing {fname}: {e}")
#     return pd.DataFrame(results)

# # Example usage:
# summary_df = batch_data_stats('/home/rishi/ML Projects/Air Pollution/sites_comb', calculate_data_stats)
# summary_df.head()

# %%
# summary_df.to_csv("summary_df.csv")
# (summary_df==0).sum(axis=0)

# %%
df=pd.read_csv(r"/home/rishi/ML Projects/Air Pollution/CPCB/visualize_median_2023/PM2.5_(µg_m³)_df_cpcb_new_limits.csv")
df.head()
# Out:
#             Unnamed: 0  site_103_CRRI_Mathura_Road_Delhi_IMD_15Min.csv  \
# 0  2023-01-01 00:00:00                                         291.620
# 1  2023-01-01 01:00:00                                         177.385
# 2  2023-01-01 02:00:00                                         165.295
# 3  2023-01-01 03:00:00                                          70.180
# 4  2023-01-01 04:00:00                                         144.625
#
#    site_104_Burari_Crossing_Delhi_IMD_15Min.csv  \
# 0                                       114.835
# 1                                       123.825
# 2                                        90.875
# 3                                       142.765
# 4                                       222.975
#
#    site_105_North_Campus_DU_Delhi_IMD_15Min.csv  \
# 0                                       129.605
# 1                                       121.805
# 2                                        98.435
# 3                                        95.235
# 4                                       101.750
#
#    site_106_IGI_Airport_(T3)_Delhi_IMD_15Min.csv  \
# 0                                         87.645
# 1                                         89.740
# 2                                         64.400
# 3                                         55.490
# 4                                         69.285
#
#    site_107_Pusa_Delhi_IMD_15Min.csv  site_108_Aya_Nagar_Delhi_IMD_15Min.csv  \
# 0                            133.580                                  69.210
# 1                            131.795                                  82.425
# 2                            148.330                                  86.110
# 3                            122.905                                  78.240
# 4                             96.390                                  61.395
#
#    site_109_Lodhi_Road_Delhi_IMD_15Min.csv  \
# 0                                  149.405
# 1                                  148.695
# 2                                  135.940
# 3                                  134.660
# 4                                  127.525
#
#    site_111_Sector_62_Noida_IMD_15Min.csv  \
# 0                                  84.065
# 1                                 117.430
# 2                                 100.530
# 3                                  84.435
# 4                                 100.855
#
#    site_113_Shadipur_Delhi_CPCB_15Min.csv  ...  \
# 0                                   166.0  ...
# 1                                   158.3  ...
# 2                                   167.8  ...
# 3                                   161.4  ...
# 4                                   119.8  ...
#
#    site_5998_Savta_Mali_Nagar_Pimpri-Chinchwad_IITM_15Min.csv  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    site_6008_Mahishkapur_Road_B-Zone_Durgapur_WBPCB_15Min.csv  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    site_6009_Dasnagar_Howrah_WBPCB_15Min.csv  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    site_6010_Police_Line_Sri_Vijaya_Puram_ANPCC_15Min.csv  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    site_6011_Amity_University_Panchgaon_IITM_15Min.csv  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    site_6012_Dhankawadi_Pune_IITM_15Min.csv  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    site_6032_Ponnusamy_Nagar_Namakkal_TNPCB_15Min.csv  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    site_6060_IIT_Delhi_Delhi_IITM_15Min.csv  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    site_6061_Khunmoh_Srinagar_JKPCC_15Min.csv  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    site_6062_Khrew_Pampore_JKPCC_15Min.csv
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# [5 rows x 565 columns]

# %%
# Get sites with <20% missing data for each pollutant and find intersection
pollutants = ["PM2.5 (µg/m³)", "PM10 (µg/m³)", "NO2 (µg/m³)", "SO2 (µg/m³)", "CO (mg/m³)", "Ozone (µg/m³)"]
threshold = 10  # 20% missing data threshold

sites_by_pollutant = {}

for pollutant in pollutants:
    df = pd.read_csv(f"/home/rishi/ML Projects/Air Pollution/CPCB/visualize_median_2023/{pollutant.replace('/', '_').replace(' ', '_')}_df_cpcb_new_limits.csv",index_col=0, parse_dates=True)
    
    # Calculate missing percentage for each column (site)
    missing_pct = df.isnull().sum(axis=0) * 100 / len(df)
    
    # Get sites with <20% missing
    good_sites = missing_pct[missing_pct < threshold].index.tolist()
    sites_by_pollutant[pollutant] = set(good_sites)
    
    print(f"{pollutant}: {len(good_sites)} sites with <{threshold}% missing")

# Find intersection of all pollutants
final_sites = set.intersection(*sites_by_pollutant.values())

print(f"\n{'='*60}")
print(f"Sites with <{threshold}% missing data for ALL pollutants: {len(final_sites)}")
print(f"{'='*60}")
# Out:
# PM2.5 (µg/m³): 184 sites with <10% missing
# PM10 (µg/m³): 186 sites with <10% missing
# NO2 (µg/m³): 216 sites with <10% missing
# SO2 (µg/m³): 204 sites with <10% missing
# CO (mg/m³): 221 sites with <10% missing
# Ozone (µg/m³): 209 sites with <10% missing
#
# ============================================================
# Sites with <10% missing data for ALL pollutants: 130
# ============================================================

# %%
131*24*365*3*6
# Out:
# 20656080

# %%
# Get sites with <20% missing data for each pollutant and find intersection
pollutants = ["PM2.5 (µg/m³)", "PM10 (µg/m³)", "NO2 (µg/m³)", "SO2 (µg/m³)", "CO (mg/m³)", "Ozone (µg/m³)"]
threshold = 20  # 20% missing data threshold

sites_by_pollutant = {}

for pollutant in pollutants:
    df = pd.read_csv(f"/home/rishi/ML Projects/Air Pollution/CPCB/visualize_median_2023/{pollutant.replace('/', '_').replace(' ', '_')}_df_cpcb_new_limits.csv",index_col=0, parse_dates=True)
    
    # Calculate missing percentage for each column (site)
    missing_pct = df.isnull().sum(axis=0) * 100 / len(df)
    
    # Get sites with <20% missing
    good_sites = missing_pct[missing_pct < threshold].index.tolist()
    sites_by_pollutant[pollutant] = set(good_sites)
    
    print(f"{pollutant}: {len(good_sites)} sites with <{threshold}% missing")

# Find intersection of all pollutants
final_sites = set.intersection(*sites_by_pollutant.values())

print(f"\n{'='*60}")
print(f"Sites with <{threshold}% missing data for ALL pollutants: {len(final_sites)}")
print(f"{'='*60}")
# Out:
# PM2.5 (µg/m³): 322 sites with <20% missing
# PM10 (µg/m³): 326 sites with <20% missing
# NO2 (µg/m³): 333 sites with <20% missing
# SO2 (µg/m³): 330 sites with <20% missing
# CO (mg/m³): 347 sites with <20% missing
# Ozone (µg/m³): 329 sites with <20% missing
#
# ============================================================
# Sites with <20% missing data for ALL pollutants: 252
# ============================================================

# %%
253*24*365*3*6
# Out:
# 39893040

# %%
# Get sites with <20% missing data for each pollutant and find intersection
pollutants = ["PM2.5 (µg/m³)", "PM10 (µg/m³)", "NO2 (µg/m³)", "SO2 (µg/m³)", "CO (mg/m³)", "Ozone (µg/m³)"]
threshold = 30  # 20% missing data threshold

sites_by_pollutant = {}

for pollutant in pollutants:
    df = pd.read_csv(f"/home/rishi/ML Projects/Air Pollution/CPCB/visualize_median_2023/{pollutant.replace('/', '_').replace(' ', '_')}_df_cpcb_new_limits.csv",index_col=0, parse_dates=True)
    
    # Calculate missing percentage for each column (site)
    missing_pct = df.isnull().sum(axis=0) * 100 / len(df)
    
    # Get sites with <20% missing
    good_sites = missing_pct[missing_pct < threshold].index.tolist()
    sites_by_pollutant[pollutant] = set(good_sites)
    
    print(f"{pollutant}: {len(good_sites)} sites with <{threshold}% missing")

# Find intersection of all pollutants
final_sites = set.intersection(*sites_by_pollutant.values())

print(f"\n{'='*60}")
print(f"Sites with <{threshold}% missing data for ALL pollutants: {len(final_sites)}")
print(f"{'='*60}")
# Out:
# PM2.5 (µg/m³): 415 sites with <30% missing
# PM10 (µg/m³): 416 sites with <30% missing
# NO2 (µg/m³): 423 sites with <30% missing
# SO2 (µg/m³): 409 sites with <30% missing
# CO (mg/m³): 430 sites with <30% missing
# Ozone (µg/m³): 412 sites with <30% missing
#
# ============================================================
# Sites with <30% missing data for ALL pollutants: 352
# ============================================================

# %%
353*365*3*24*6
# Out:
# 55661040

# %%
import pandas as pd
# Filter sites by maximum gap length for each pollutant and find intersection
import numpy as np

pollutants = ["PM2.5 (µg/m³)", "PM10 (µg/m³)", "NO2 (µg/m³)", "SO2 (µg/m³)", "CO (mg/m³)", "Ozone (µg/m³)"]
max_gap_hours = 336 # Set your desired maximum gap length (in hours)

sites_by_pollutant_gap = {}

for pollutant in pollutants:
    df = pd.read_csv(f"/home/rishi/ML Projects/Air Pollution/CPCB/visualize_median_2023/{pollutant.replace('/', '_').replace(' ', '_')}_df_cpcb_new_limits.csv",index_col=0, parse_dates=True)
    
    good_sites = []
    for site in df.columns:
        # Find gaps for this site
        is_missing = df[site].isnull().values
        gap_lengths = []
        current_gap = 0
        for missing in is_missing:
            if missing:
                current_gap += 1
            else:
                if current_gap > 0:
                    gap_lengths.append(current_gap)
                    current_gap = 0
        if current_gap > 0:
            gap_lengths.append(current_gap)
        
        # Check max gap length (in hours)
        if len(gap_lengths) == 0 or np.max(gap_lengths) <= max_gap_hours:
            good_sites.append(site)
    sites_by_pollutant_gap[pollutant] = set(good_sites)
    print(f"{pollutant}: {len(good_sites)} sites with max gap <= {max_gap_hours} hours")

# Find intersection of all pollutants
final_sites_gap = set.intersection(*sites_by_pollutant_gap.values())

print(f"\n{'='*60}")
print(f"Sites with max gap <= {max_gap_hours} hours for ALL pollutants: {len(final_sites_gap)}")
print(f"{'='*60}")
# Out:
# PM2.5 (µg/m³): 209 sites with max gap <= 336 hours
# PM10 (µg/m³): 212 sites with max gap <= 336 hours
# NO2 (µg/m³): 196 sites with max gap <= 336 hours
# SO2 (µg/m³): 208 sites with max gap <= 336 hours
# CO (mg/m³): 208 sites with max gap <= 336 hours
# Ozone (µg/m³): 208 sites with max gap <= 336 hours
#
# ============================================================
# Sites with max gap <= 336 hours for ALL pollutants: 140
# ============================================================

# %%
with open("site_list.txt", "w") as f:
    for site in final_sites_gap:
        f.write(f"{site}\n")
print("Site list written to site_list.txt")
# Out:
# Site list written to site_list.txt

# %%
141*24*365*3*6
# Out:
# 22232880

# %%
x=set.intersection(set(final_sites_gap), set(final_sites))
len(x)
# Out:
# 138

# %%
24*14
# Out:
# 336
