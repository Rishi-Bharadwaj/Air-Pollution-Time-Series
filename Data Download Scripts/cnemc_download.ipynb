# %%
https://quotsoft.net/air/data/china_sites_20151201.csv
https://quotsoft.net/air/data/beijing_all_20131205.csv

# %%
https://quotsoft.net/imd/data/china_sites_20151201.csv

# %%
import pandas as pd

dates=pd.date_range(start="2014-05-13", end="2025-12-31", freq="D")
dates= dates.strftime("%Y%m%d").to_list()
dates
# Out:
# ['20140513',
#  '20140514',
#  '20140515',
#  '20140516',
#  '20140517',
#  '20140518',
#  '20140519',
#  '20140520',
#  '20140521',
#  '20140522',
#  '20140523',
#  '20140524',
#  '20140525',
#  '20140526',
#  '20140527',
#  '20140528',
#  '20140529',
#  '20140530',
#  '20140531',
#  '20140601',
#  '20140602',
#  '20140603',
#  '20140604',
#  '20140605',
#  '20140606',
#  '20140607',
#  '20140608',
#  '20140609',
#  '20140610',
#  '20140611',
#  '20140612',
#  '20140613',
#  '20140614',
#  '20140615',
#  '20140616',
#  '20140617',
#  '20140618',
#  '20140619',
#  '20140620',
#  '20140621',
#  '20140622',
#  '20140623',
#  '20140624',
#  '20140625',
#  '20140626',
#  '20140627',
#  '20140628',
#  '20140629',
#  '20140630',
#  '20140701',
#  '20140702',
#  '20140703',
#  '20140704',
#  '20140705',
#  '20140706',
#  '20140707',
#  '20140708',
#  '20140709',
#  '20140710',
#  '20140711',
#  '20140712',
#  '20140713',
#  '20140714',
#  '20140715',
#  '20140716',
#  '20140717',
# ...

# %%
url_list=[]
for date in dates:
    url=f"https://quotsoft.net/air/data/china_sites_{date}.csv"
    url_list.append(url)
url_list

with open("cnemc_urls.txt", 'w') as f:
    f.write("\n".join(url_list))
