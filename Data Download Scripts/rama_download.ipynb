# %%
https://aire.cdmx.gob.mx/descargas/Opendata/Bases_publicas/RAMA/86RAMA.zip

https://aire.cdmx.gob.mx/descargas/Opendata/Bases_publicas/REDMA/89REDMA.zip

https://aire.cdmx.gob.mx/descargas/Opendata/Bases_publicas/REDMET/86REDMET.zip

# %%
urls=[]
for year in range(2000, 2026):
    s=str(year)[2:]
    url1=f"https://aire.cdmx.gob.mx/descargas/Opendata/Bases_publicas/RAMA/{s}RAMA.zip"
    url2=f"https://aire.cdmx.gob.mx/descargas/Opendata/Bases_publicas/REDMET/{s}REDMET.zip"
    urls.append(url1)
    urls.append(url2)
urls
# Out:
# ['https://aire.cdmx.gob.mx/descargas/Opendata/Bases_publicas/RAMA/00RAMA.zip',
#  'https://aire.cdmx.gob.mx/descargas/Opendata/Bases_publicas/REDMET/00REDMET.zip',
#  'https://aire.cdmx.gob.mx/descargas/Opendata/Bases_publicas/RAMA/01RAMA.zip',
#  'https://aire.cdmx.gob.mx/descargas/Opendata/Bases_publicas/REDMET/01REDMET.zip',
#  'https://aire.cdmx.gob.mx/descargas/Opendata/Bases_publicas/RAMA/02RAMA.zip',
#  'https://aire.cdmx.gob.mx/descargas/Opendata/Bases_publicas/REDMET/02REDMET.zip',
#  'https://aire.cdmx.gob.mx/descargas/Opendata/Bases_publicas/RAMA/03RAMA.zip',
#  'https://aire.cdmx.gob.mx/descargas/Opendata/Bases_publicas/REDMET/03REDMET.zip',
#  'https://aire.cdmx.gob.mx/descargas/Opendata/Bases_publicas/RAMA/04RAMA.zip',
#  'https://aire.cdmx.gob.mx/descargas/Opendata/Bases_publicas/REDMET/04REDMET.zip',
#  'https://aire.cdmx.gob.mx/descargas/Opendata/Bases_publicas/RAMA/05RAMA.zip',
#  'https://aire.cdmx.gob.mx/descargas/Opendata/Bases_publicas/REDMET/05REDMET.zip',
# ...

# %%
x=str(2000)
x[:2]
# Out:
# '20'

# %%
with open("sinaica_urls.txt", 'w') as f:
    f.write("\n".join(urls))
